# %% [markdown]
# # A-Share Market Data Smoke Test
# 使用  拉取平安银行日线，并保存到 。

# %%
from a_share_research import fetch_stock_history, project_root

root = project_root()
df = fetch_stock_history()
df.head()

# %%
raw_path = root / 'data' / 'raw' / '000001_from_notebook.parquet'
df.to_parquet(raw_path, index=False)
raw_path

# %%
df['收盘'].plot(title='000001 Daily Close')
